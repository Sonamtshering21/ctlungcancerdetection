# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import matplotlib.pyplot as plt

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

# Define image parameters
img_size = 128
batch_size = 32
epochs = 15

# Path to your dataset folders
train_dir = "data/train"
val_dir = "data/valid"
test_dir = "data/test"

# Image data generators (rescaling and augmentation for training)
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    zoom_range=0.1,
    horizontal_flip=True
)
val_test_datagen = ImageDataGenerator(rescale=1./255)

# Create generators
train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical'
)

val_data = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical'
)

test_data = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Automatically detect number of classes
num_classes = train_data.num_classes

# Build CNN model
model = Sequential([
    Input(shape=(img_size, img_size, 3)),

    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Flatten(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')  # Dynamic class count
])

# Compile model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train model
history = model.fit(
    train_data,
    epochs=epochs,
    validation_data=val_data
)

# Evaluate on test set
test_loss, test_acc = model.evaluate(test_data)
print(f"\nTest accuracy: {test_acc:.4f}")

# Save the model
model.save("lung_cancer_cnn_model.h5")
# Out:
# Found 613 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.
# Found 315 images belonging to 4 classes.
# Epoch 1/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.2975 - loss: 1.3511 - val_accuracy: 0.1806 - val_loss: 1.3794
# Epoch 2/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 402ms/step - accuracy: 0.3919 - loss: 1.2672 - val_accuracy: 0.4306 - val_loss: 1.2870
# Epoch 3/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.4634 - loss: 1.1878 - val_accuracy: 0.5139 - val_loss: 1.1905
# Epoch 4/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 352ms/step - accuracy: 0.4644 - loss: 1.1683 - val_accuracy: 0.5000 - val_loss: 1.1625
# Epoch 5/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.5125 - loss: 1.0620 - val_accuracy: 0.3611 - val_loss: 1.1757
# Epoch 6/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 354ms/step - accuracy: 0.5356 - loss: 1.0574 - val_accuracy: 0.5833 - val_loss: 1.0124
# Epoch 7/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 349ms/step - accuracy: 0.6085 - loss: 0.9524 - val_accuracy: 0.5556 - val_loss: 1.0402
# Epoch 8/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.6753 - loss: 0.8350 - val_accuracy: 0.5972 - val_loss: 1.0254
# Epoch 9/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 348ms/step - accuracy: 0.6850 - loss: 0.7738 - val_accuracy: 0.6389 - val_loss: 0.8836
# Epoch 10/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 353ms/step - accuracy: 0.7014 - loss: 0.7521 - val_accuracy: 0.6528 - val_loss: 0.8861
# Epoch 11/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.7306 - loss: 0.6701 - val_accuracy: 0.6667 - val_loss: 0.8706
# Epoch 12/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.7481 - loss: 0.6601 - val_accuracy: 0.6944 - val_loss: 0.8855
# Epoch 13/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 349ms/step - accuracy: 0.7365 - loss: 0.6445 - val_accuracy: 0.6528 - val_loss: 0.8744
# Epoch 14/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 376ms/step - accuracy: 0.7711 - loss: 0.6433 - val_accuracy: 0.6944 - val_loss: 0.8636
# Epoch 15/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 385ms/step - accuracy: 0.7981 - loss: 0.5855 - val_accuracy: 0.6528 - val_loss: 0.8812
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 611ms/step - accuracy: 0.2630 - loss: 3.8860
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test accuracy: 0.3810

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Input

# Parameters
img_size = 224  # ResNet50 prefers 224x224
batch_size = 32
epochs = 10

# Directories
train_dir = 'data/train'
val_dir = 'data/valid'

# Data preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)
val_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical'
)
val_data = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical'
)

# Load pretrained model without top
base_model = ResNet50(include_top=False, weights='imagenet', input_tensor=Input(shape=(img_size, img_size, 3)))

# Freeze base model
base_model.trainable = False

# Add your custom classifier
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(train_data.num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# Compile
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=epochs
)

# Optionally: Unfreeze and fine-tune
# base_model.trainable = True
# model.compile(...)
# model.fit(...)
# Out:
# Found 613 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 102s 1us/step
# Epoch 1/10
# C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_22']
# Received: inputs=Tensor(shape=(None, 224, 224, 3))
#   warnings.warn(msg)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.2645 - loss: 1.8774 - val_accuracy: 0.4167 - val_loss: 1.3617
# Epoch 2/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.3144 - loss: 1.4832 - val_accuracy: 0.4583 - val_loss: 1.2980
# Epoch 3/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.3654 - loss: 1.4106 - val_accuracy: 0.4583 - val_loss: 1.2710
# Epoch 4/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.3614 - loss: 1.3605 - val_accuracy: 0.4722 - val_loss: 1.2370
# Epoch 5/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.4242 - loss: 1.2822 - val_accuracy: 0.4861 - val_loss: 1.2041
# Epoch 6/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.4102 - loss: 1.2494 - val_accuracy: 0.4722 - val_loss: 1.1843
# Epoch 7/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.4267 - loss: 1.1995 - val_accuracy: 0.4722 - val_loss: 1.1658
# Epoch 8/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.5428 - loss: 1.1451 - val_accuracy: 0.4861 - val_loss: 1.1619
# Epoch 9/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.4770 - loss: 1.1427 - val_accuracy: 0.4722 - val_loss: 1.1299
# Epoch 10/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.4961 - loss: 1.1200 - val_accuracy: 0.4861 - val_loss: 1.1186

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 16
NUM_CLASSES = 4
EPOCHS_INITIAL = 10
EPOCHS_FINE_TUNE = 10
DATASET_PATH = "data"

# Data Generators
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

val_test_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow_from_directory(
    os.path.join(DATASET_PATH, 'train'),
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_data = val_test_gen.flow_from_directory(
    os.path.join(DATASET_PATH, 'valid'),
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

test_data = val_test_gen.flow_from_directory(
    os.path.join(DATASET_PATH, 'test'),
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Model
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(*IMAGE_SIZE, 3))
for layer in base_model.layers:
    layer.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
output = Dense(NUM_CLASSES, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=output)

model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, verbose=1)
checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, monitor='val_accuracy', mode='max', verbose=1)

# Initial Training
model.fit(train_data,
          epochs=EPOCHS_INITIAL,
          validation_data=val_data,
          callbacks=[lr_scheduler, checkpoint])

# Fine-tuning
for layer in base_model.layers[-30:]:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_data,
          epochs=EPOCHS_FINE_TUNE,
          validation_data=val_data,
          callbacks=[lr_scheduler, checkpoint])

# Load best model
model.load_weights('best_model.h5')

# Evaluation on test set
test_data.reset()
Y_true = test_data.classes
Y_pred = model.predict(test_data)
Y_pred_classes = np.argmax(Y_pred, axis=1)
class_labels = list(test_data.class_indices.keys())

# Metrics
print("\n📊 Classification Report:\n")
print(classification_report(Y_true, Y_pred_classes, target_names=class_labels))

print("🧩 Confusion Matrix:\n")
conf_matrix = confusion_matrix(Y_true, Y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', xticklabels=class_labels, yticklabels=class_labels, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()
# Out:
# Found 613 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.
# Found 315 images belonging to 4 classes.
# C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 919ms/step - accuracy: 0.3654 - loss: 1.3273
# Epoch 1: val_accuracy improved from -inf to 0.36111, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.3660 - loss: 1.3262 - val_accuracy: 0.3611 - val_loss: 1.1890 - learning_rate: 0.0010
# Epoch 2/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 878ms/step - accuracy: 0.5027 - loss: 1.1879
# Epoch 2: val_accuracy improved from 0.36111 to 0.45833, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.5025 - loss: 1.1875 - val_accuracy: 0.4583 - val_loss: 1.2234 - learning_rate: 0.0010
# Epoch 3/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 918ms/step - accuracy: 0.4870 - loss: 1.0924
# Epoch 3: val_accuracy did not improve from 0.45833
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.4874 - loss: 1.0924 - val_accuracy: 0.4583 - val_loss: 1.0684 - learning_rate: 0.0010
# Epoch 4/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 915ms/step - accuracy: 0.5269 - loss: 1.0535
# Epoch 4: val_accuracy improved from 0.45833 to 0.47222, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.5265 - loss: 1.0534 - val_accuracy: 0.4722 - val_loss: 1.0333 - learning_rate: 0.0010
# Epoch 5/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 940ms/step - accuracy: 0.5357 - loss: 1.0020
# Epoch 5: val_accuracy did not improve from 0.47222
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.5357 - loss: 1.0028 - val_accuracy: 0.4583 - val_loss: 1.0249 - learning_rate: 0.0010
# Epoch 6/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.5078 - loss: 1.0119
# Epoch 6: val_accuracy did not improve from 0.47222
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 38s 971ms/step - accuracy: 0.5088 - loss: 1.0119 - val_accuracy: 0.4722 - val_loss: 1.0140 - learning_rate: 0.0010
# Epoch 7/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - accuracy: 0.5358 - loss: 1.0054
# Epoch 7: val_accuracy improved from 0.47222 to 0.50000, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 39s 988ms/step - accuracy: 0.5356 - loss: 1.0053 - val_accuracy: 0.5000 - val_loss: 1.0088 - learning_rate: 0.0010
# Epoch 8/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 912ms/step - accuracy: 0.5930 - loss: 0.9496
# Epoch 8: val_accuracy did not improve from 0.50000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.5919 - loss: 0.9509 - val_accuracy: 0.4722 - val_loss: 1.0132 - learning_rate: 0.0010
# Epoch 9/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 968ms/step - accuracy: 0.5163 - loss: 1.0203
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 9: val_accuracy did not improve from 0.50000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.5169 - loss: 1.0200 - val_accuracy: 0.4861 - val_loss: 1.0369 - learning_rate: 0.0010
# Epoch 10/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - accuracy: 0.5367 - loss: 0.9967
# Epoch 10: val_accuracy did not improve from 0.50000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 37s 953ms/step - accuracy: 0.5371 - loss: 0.9969 - val_accuracy: 0.4722 - val_loss: 1.0377 - learning_rate: 5.0000e-04
# Epoch 1/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2618 - loss: 9.1237
# Epoch 1: val_accuracy did not improve from 0.50000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.2642 - loss: 9.0310 - val_accuracy: 0.3333 - val_loss: 1.3446 - learning_rate: 1.0000e-05
# Epoch 2/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5564 - loss: 2.1654
# Epoch 2: val_accuracy did not improve from 0.50000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.5568 - loss: 2.1507 - val_accuracy: 0.2083 - val_loss: 1.5329 - learning_rate: 1.0000e-05
# Epoch 3/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5544 - loss: 1.0090
# Epoch 3: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 3: val_accuracy did not improve from 0.50000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.5544 - loss: 1.0116 - val_accuracy: 0.2083 - val_loss: 1.5179 - learning_rate: 1.0000e-05
# Epoch 4/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5683 - loss: 0.9835
# Epoch 4: val_accuracy did not improve from 0.50000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.5681 - loss: 0.9840 - val_accuracy: 0.2361 - val_loss: 1.3155 - learning_rate: 5.0000e-06
# Epoch 5/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5856 - loss: 0.9547
# Epoch 5: val_accuracy did not improve from 0.50000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.5857 - loss: 0.9552 - val_accuracy: 0.5000 - val_loss: 1.1121 - learning_rate: 5.0000e-06
# Epoch 6/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6324 - loss: 0.9752
# Epoch 6: val_accuracy did not improve from 0.50000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.6318 - loss: 0.9751 - val_accuracy: 0.4861 - val_loss: 1.0260 - learning_rate: 5.0000e-06
# Epoch 7/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5934 - loss: 0.8986
# Epoch 7: val_accuracy did not improve from 0.50000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.5928 - loss: 0.8998 - val_accuracy: 0.4861 - val_loss: 1.0129 - learning_rate: 5.0000e-06
# Epoch 8/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6105 - loss: 0.8918
# Epoch 8: val_accuracy did not improve from 0.50000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.6102 - loss: 0.8928 - val_accuracy: 0.4722 - val_loss: 1.0026 - learning_rate: 5.0000e-06
# Epoch 9/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5815 - loss: 0.9235
# Epoch 9: val_accuracy did not improve from 0.50000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.5818 - loss: 0.9229 - val_accuracy: 0.4861 - val_loss: 1.0160 - learning_rate: 5.0000e-06
# Epoch 10/10
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5760 - loss: 0.8654
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 10: val_accuracy did not improve from 0.50000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.5760 - loss: 0.8662 - val_accuracy: 0.4722 - val_loss: 1.0214 - learning_rate: 5.0000e-06
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step
#
# 📊 Classification Report:
# C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                          precision    recall  f1-score   support
#
#          adenocarcinoma       0.48      0.90      0.63       120
#    large.cell.carcinoma       0.33      0.18      0.23        51
#                  normal       0.84      1.00      0.92        54
# squamous.cell.carcinoma       0.00      0.00      0.00        90
#
#                accuracy                           0.54       315
#               macro avg       0.41      0.52      0.44       315
#            weighted avg       0.38      0.54      0.43       315
#
# 🧩 Confusion Matrix:

# %%
# Import necessary libraries
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
import os
import matplotlib.pyplot as plt

# Load the saved model
model = load_model('best_model.h5')

# Set image size as per your model's requirement
IMAGE_SIZE = (224, 224)

# Function to load and preprocess the new image
def preprocess_image(image_path):
    img = image.load_img(image_path, target_size=IMAGE_SIZE)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = img_array / 255.0  # Rescale pixel values
    return img_array

# Test with a single image
image_path = 'data/check/1.png'  # Path to your test image
img_array = preprocess_image(image_path)

# Predict the class of the image
predictions = model.predict(img_array)
predicted_class = np.argmax(predictions, axis=1)  # Get class with highest probability

# Print the result
class_labels = ['adenocarcinoma', 'large.cell.carcinoma', 'normal', 'squamous.cell.carcinoma']  # Replace with your class labels
predicted_class_label = class_labels[predicted_class[0]]
print(f"The predicted class is: {predicted_class_label}")

# If you want to show the image
img = image.load_img(image_path)
plt.imshow(img)
plt.title(f"Predicted: {predicted_class_label}")
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# The predicted class is: adenocarcinoma

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
import os
import matplotlib.pyplot as plt

# Load the saved model
model = load_model('best_model.h5')

# Set image size as per your model's requirement
IMAGE_SIZE = (224, 224)

# Class labels (replace with yours)
class_labels = ['adenocarcinoma', 'large.cell.carcinoma', 'normal', 'squamous.cell.carcinoma']

# Path to the folder containing test images
test_folder = 'data/check/'  # Folder with multiple images

# Loop through all images in the folder
for img_file in os.listdir(test_folder):
    if img_file.endswith(('.png', '.jpg', '.jpeg')):  # Check for image files
        image_path = os.path.join(test_folder, img_file)
        
        # Preprocess the image
        img = image.load_img(image_path, target_size=IMAGE_SIZE)
        img_array = image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
        img_array = img_array / 255.0  # Rescale pixel values

        # Predict the class
        predictions = model.predict(img_array)
        predicted_class = np.argmax(predictions, axis=1)
        predicted_label = class_labels[predicted_class[0]]

        # Print & show results
        print(f"Image: {img_file} | Predicted: {predicted_label}")
        
        plt.imshow(img)
        plt.title(f"Predicted: {predicted_label}")
        plt.axis('off')  # Hide axes
        plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:5 out of the last 23 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000012619B6E0C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 23 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000012619B6E0C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Image: 1.png | Predicted: adenocarcinoma
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# Image: 2.png | Predicted: adenocarcinoma
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# Image: 3.png | Predicted: normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# Image: 4.png | Predicted: adenocarcinoma
